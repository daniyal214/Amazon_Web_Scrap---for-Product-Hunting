# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.amazon.co.uk/s?rh=n%3A59624031%2Cp_72%3A4-&pf_rd_i=59624031&pf_rd_p=2f305edc-69a0-5064-a370-836e442d53be&pf_rd_r=FGRC550H48M4QY84GW2A&pf_rd_s=merchandised-search-10&pf_rd_t=BROWSE&refresh=4&ref=glow_cls'

headers = {"User-Agent": "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:79.0) Gecko/20100101 Firefox/79.0"}

# %%
response = requests.get(url, headers = headers)

# %%
response.ok
# Out:
# True

# %%
content = response.content

# %%
response.headers
# Out:
# {'Content-Type': 'text/html;charset=UTF-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Server': 'Server', 'Date': 'Tue, 25 May 2021 15:57:18 GMT', 'x-amz-rid': '9B69KMR0W9NE80Y7HFFB', 'set-cookie': 'session-id=261-7504766-5490965; Domain=.amazon.co.uk; Expires=Wed, 25-May-2022 15:57:18 GMT; Path=/; Secure, session-id-time=2082787201l; Domain=.amazon.co.uk; Expires=Wed, 25-May-2022 15:57:18 GMT; Path=/; Secure, i18n-prefs=GBP; Domain=.amazon.co.uk; Expires=Wed, 25-May-2022 15:57:18 GMT; Path=/', 'Content-Encoding': 'gzip', 'X-XSS-Protection': '1;', 'Pragma': 'no-cache', 'Content-Language': 'en-GB', 'Accept-CH': 'ect,rtt,downlink', 'Accept-CH-Lifetime': '86400', 'Cache-Control': 'no-cache', 'X-Content-Type-Options': 'nosniff', 'Expires': '-1', 'Strict-Transport-Security': 'max-age=47474747; includeSubDomains; preload', 'Vary': 'Content-Type,X-Amazon-Wtm-Tag-SP-Search-Secured-Port-Enabled,Accept-Encoding,X-Amzn-CDN-Cache,X-Amzn-AX-Treatment,User-Agent', 'X-Frame-Option
# ...

# %%
read = BeautifulSoup(content, 'lxml')

# %%
read
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-gb"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <script type="text/javascript">var ue_t0=ue_t0||+new Date();</script>
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link href="https://completion.amazon.com" rel="dns-prefetch"/>
# <script type="text/javascript">
# window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
#     ue_hob = +new Date();
# ...

# %%
card = 'https://www.amazon.co.uk' + read.find_all('div', class_ = 'a-section a-spacing-medium')[1].h2.a.get('href')

# %%
read.find_all('div', class_ = 'a-section a-spacing-medium')
# Out:
# [<div class="a-section a-spacing-medium"><div class="a-section a-spacing-micro s-grid-status-badge-container"><a class="a-link-normal" href="/gp/bestsellers/baby/ref=sr_bs_0_baby_1"><span class="rush-component" data-component-props='{"badgeType":"best-seller","asin":"B08MXSBRSB"}' data-component-type="s-status-badge-component"><div class="a-row a-badge-region"><span aria-labelledby="B08MXSBRSB-best-seller-label B08MXSBRSB-best-seller-supplementary" class="a-badge" data-a-badge-supplementary-position="right" data-a-badge-type="status" id="B08MXSBRSB-best-seller" tabindex="0"><span aria-hidden="true" class="a-badge-label" data-a-badge-color="sx-orange" id="B08MXSBRSB-best-seller-label"><span class="a-badge-label-inner a-text-ellipsis"><span class="a-badge-text" data-a-badge-color="sx-cloud">Best Seller</span></span></span><span aria-hidden="true" class="a-badge-supplementary-text a-text-ellipsis" id="B08MXSBRSB-best-seller-supplementary">in Baby Products</span></span></div></span> </a>
# ...

# %%
for i in range(len(read.find_all('div', class_ = 'a-section a-spacing-medium'))):
    card = 'https://www.amazon.co.uk' + read.find_all('div', 
                                                      class_ = 'a-section a-spacing-medium')[i].h2.a.get('href')
    url2 = card
    headers = {"User-Agent": "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:79.0) Gecko/20100101 Firefox/79.0"}
    res2 = requests.get(url2, headers=headers)
    cont2 = res2.content  
    read2 = BeautifulSoup(cont2, 'html.parser')
    print(read2.find_all('h1', id = 'title')[0].text.strip())
    print()
# Out:
# WaterWipes Baby Wipes Sensitive Newborn Biodegradable Unscented, 99.9% Water, 720 Wet Wipes (12 Packs Of 60 Wipes)
#
# Amazon Brand – Mama Bear Sensitive Unscented baby wipes– Pack of 18 (Total 1008 wipes)
#
# Johnson's Baby Cotton Buds, Pack of 200
#
# The Gro Company Stars and Moons Gro Anywhere Portable Blackout Blind with Suction Cups
#
# Bio-Oil, Skincare Oil Improve the Appearance of Scars Stretch Marks and Uneven Skin Tone, 200 ml
#
# Tommee Tippee Replacement Filter for the Perfect Prep Original and Day & Night Baby Bottle Maker Machines, Pack of 1
#
# Lansinoh HPA Lanolin Nipple Cream 40ml for Breastfeeding New mums
#
# Bepanthen Nappy Care Ointment | Nappy Cream with Provitamin B5 that Helps to Protect from the causes of Nappy Rash and Aids Natural Recovery of Skin | Suitable for Newborns Skin, 100 g
#
# Huggies Pure Baby Wipes Bulk - 99 Percent Water, Sensitive, Fragrance Free, 18 Packs, 56 Count (1,008 Wet Wipes Total)
#
# Lansinoh Disposable Nursing Pads (60 Piece Pack)
# ...

# %%
id_ = []
for i in range(len(read2.find_all('div'))):
    id_.append(read2.find_all('div')[i].get('id'))

# %%
id_
# Out:
# ['a-page',
#  None,
#  'sp-cc-error',
#  None,
#  None,
#  None,
#  'nav-upnav',
#  'navbar',
#  'nav-belt',
#  None,
#  'nav-logo',
#  'nav-global-location-slot',
#  'nav-packard-glow-loc-icon',
#  'glow-ingress-block',
#  'nav-global-location-toaster-script-container',
#  None,
#  'nav-search',
#  'nav-bar-left',
#  None,
#  'nav-search-dropdown-card',
#  None,
#  None,
#  None,
#  None,
#  'nav-iss-attach',
#  None,
#  None,
#  None,
#  'nav-tools',
#  None,
#  'nav-cart-count-container',
#  'nav-cart-text-container',
#  'nav-main',
#  None,
#  None,
#  'nav-shop',
#  'nav-xshop-container',
#  'nav-xshop',
#  None,
#  'nav-swmslot',
#  'navSwmHoliday',
#  'nav-subnav-toaster',
#  'nav-progressive-subnav',
#  'nav-subnav',
#  'nav-flyout-ewc',
#  None,
#  None,
#  None,
#  'dp',
#  'percolate-ui-ilm_div',
#  None,
#  None,
#  'universal-detail-ilm',
#  None,
#  'rw-swatch-image_div',
#  'cp-merchandising-widget_div',
#  'prime_div',
#  None,
#  'PrimeStripeContent',
#  None,
# ...

# %%
import re
import numpy as np

# %%
id_[1]

# %%
re.search(r'(.)', id_[2])
# Out:
# <re.Match object; span=(0, 1), match='s'>

# %%
pattern = 'price'

for i in range(len(id_)):
    r = re.search(r'(.)', id_[i])
    if r != np.nan:
        print(r.group(0))
# Out:
# a
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-7a3dd2d56580> in <module>
#       2
#       3 for i in range(len(id_)):
# ----> 4     r = re.search(r'(.)', id_[i])
#       5     if r != np.nan:
#       6         print(r.group(0))
#
# ~/anaconda3/lib/python3.8/re.py in search(pattern, string, flags)
#     199     """Scan through string looking for a match to the pattern, returning
#     200     a Match object, or None if no match was found."""
# --> 201     return _compile(pattern, flags).search(string)
#     202
#     203 def sub(pattern, repl, string, count=0, flags=0):
#
# TypeError: expected string or bytes-like object

# %%
read2.find_all('span', class_ = 'nav-line-2 nav-progressive-content')
# Out:
# [<span class="nav-line-2 nav-progressive-content" id="glow-ingress-line2">
#                     Netherlands
#                  </span>]

# %%
# read.find_all('h2')
# Out:
# [<h2 class="a-size-mini a-spacing-none a-color-base s-line-clamp-4"><a class="a-link-normal a-text-normal" href="/WaterWipes-Sensitive-Newborn-Biodegradable-Unscented/dp/B08MXSBRSB/ref=sr_1_1?dchild=1&amp;pf_rd_i=59624031&amp;pf_rd_p=2f305edc-69a0-5064-a370-836e442d53be&amp;pf_rd_r=FGRC550H48M4QY84GW2A&amp;pf_rd_s=merchandised-search-10&amp;pf_rd_t=BROWSE&amp;qid=1621958238&amp;rdc=1&amp;refinements=p_72%3A419153031&amp;refresh=4&amp;s=baby&amp;sr=1-1"><span class="a-size-base-plus a-color-base a-text-normal">WaterWipes Baby Wipes Sensitive Newborn Biodegradable Unscented, 99.9% Water, 720 Wet Wipes (12 Packs Of 60 Wipes)</span> </a> </h2>,
# ...

# %%
# read.find_all('div', class_ = 'a-section a-spacing-medium')
# Out:
# [<div class="a-section a-spacing-medium"><div class="a-section a-spacing-micro s-grid-status-badge-container"><a class="a-link-normal" href="/gp/bestsellers/baby/ref=sr_bs_0_baby_1"><span class="rush-component" data-component-props='{"badgeType":"best-seller","asin":"B08MXSBRSB"}' data-component-type="s-status-badge-component"><div class="a-row a-badge-region"><span aria-labelledby="B08MXSBRSB-best-seller-label B08MXSBRSB-best-seller-supplementary" class="a-badge" data-a-badge-supplementary-position="right" data-a-badge-type="status" id="B08MXSBRSB-best-seller" tabindex="0"><span aria-hidden="true" class="a-badge-label" data-a-badge-color="sx-orange" id="B08MXSBRSB-best-seller-label"><span class="a-badge-label-inner a-text-ellipsis"><span class="a-badge-text" data-a-badge-color="sx-cloud">Best Seller</span></span></span><span aria-hidden="true" class="a-badge-supplementary-text a-text-ellipsis" id="B08MXSBRSB-best-seller-supplementary">in Baby Products</span></span></div></span> </a>
# ...

# %%
# url2 = card
# headers = {"User-Agent": "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:79.0) Gecko/20100101 Firefox/79.0"}

# res2 = requests.get(url2, headers=headers)

# %%
# res2.ok
# Out:
# True

# %%
# cont2 = res2.content

# %%
# read2 = BeautifulSoup(cont2, 'html.parser')

# %%
# read2.find_all('h1', id = 'title')[0].text.strip()
# Out:
# 'Calpol Saline Nasal Spray, 15ml'

# %%
# read2.find_all('span', id = 'priceblock_ourprice')[0].text
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-19-afb9ee30fb8f> in <module>
# ----> 1 read2.find_all('span', id = 'priceblock_ourprice')[0].text
#
# IndexError: list index out of range
